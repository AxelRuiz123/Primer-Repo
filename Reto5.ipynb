# %% [markdown]
# # Reto 5:
#
# ---

# %% [markdown]
# ## Ejercicio 1: Funciones

# %% [markdown]
# De nuestro código que evaluaba cual era una el número mayor, convertirla a función.
#
# Entrada: num1, num2
#
# Salida:
#
# 1. El num1 es mayor que num2
# 2. El num2 es mayor que num2
# 3. Ambos son iguales

# %%
def mayor(n1,n2):
    if (n1 > n2):
        print(n1,"Es mas grande")
    elif (n1 < n2):
        print(n2,"Es mas grande")
    else:
        print("Ambos numero son iguales")
mayor(9,7)
# Out:
# 9 Es mas grande

# %% [markdown]
# ## Ejercicio 2:

# %% [markdown]
# Crear una función que reciba como parameto un texto y que devuelva en el `return` una lista que contenga cada palabra del texto.
#
# |Entrada | Salida |
# | - | - |
# | "El señor de los anillos" | ["El", "señor", "de", "los", "anillos"] |
#
#
#
# Utiliar el metodo .split() al texto
#
# **Ejemplo**
#
# "Buenos días".split()

# %%
def split(texto):
    return texto.split()
texto="El señor de los anillos"
split(texto)
# Out:
# ['El', 'señor', 'de', 'los', 'anillos']

# %% [markdown]
# ## Ejercicio 3:

# %% [markdown]
# Un piloto de carreras ha registrado su velocidad cada segundo en la siguiente lista:
#
# velocidad = [0, 60, 80, 117, 140, 155, 170, 189, 205, 223, 234, 239, 234, 227, 215, 180, 155, 160, 189, 206, 235]
#
# Hacer una función que imprima en que segundo el piloto rebaso los 210 km/h
#
#
# **Ejemplo de impresión**
#
# En el segundo `9` el piloto llego a los `223` km/h

# %%
def piloto(velocidades):
    segundos=0
    for velocidad in velocidades:
        if velocidad > 210:
            print(f"En el segundo{segundos} el piloto {velocidad}")
        segundos=segundos+1
a=[0, 60, 80, 117, 140, 155, 170, 189, 205, 223, 234, 239, 234, 227, 215, 180, 155, 160, 189, 206, 235]
piloto(a)
# Out:
# En el segundo9 el piloto 223
# En el segundo10 el piloto 234
# En el segundo11 el piloto 239
# En el segundo12 el piloto 234
# En el segundo13 el piloto 227
# En el segundo14 el piloto 215
# En el segundo20 el piloto 235

# %% [markdown]
# ## Extra points

# %% [markdown]
# Hacer una función que nos imprima cuantos números pares e impares tiene una lista.
#
# Para evaluar un par o impar puedes utilizar el
#
# ```Python
# if numero%2 = 0:
#     print("numero es par")
# else:
#     print("numero es impar")
# ```
#
# |Entrada | Salida |
# | - | - |
# | [2,3,6,8,9] | Tiene `3` pares y `2` inpares |

# %%
def esPar(lista):
    par=0
    impar=0
    for numero in lista:
        if numero % 2 == 0:
            par+=1
        else:
            impar+=1
    print("Tiene",par,"pares y",impar,"impares")
esPar([9,10,8,1,6])
# Out:
# Tiene 3 pares y 2 impares

# %%
def high_and_low(numbers):
    numeros=[]
    numeros = numbers.split()
    numeros.sort()
    print(numeros[0]," ",numeros[-1])
    
high_and_low("1 2 3 4 5")
# Out:
# 1   5
